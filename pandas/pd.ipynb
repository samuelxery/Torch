# %%
import pandas as pd
df = pd.read_json("test.jsonl", lines=True)

# %%
df
# Out:
#          text  label
# 0   i love AI      1
# 1  this sucks      0
# 2  AI is cool      1
# 3        None      0

# %%
df = df.dropna()

# %%
df
# Out:
#          text  label
# 0   i love AI      1
# 1  this sucks      0
# 2  AI is cool      1

# %%
df["text"] = df["text"].str.lower()
# Out:
# /tmp/ipykernel_366109/2070785541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"] = df["text"].str.lower()

# %%
df
# Out:
#          text  label
# 0   i love ai      1
# 1  this sucks      0
# 2  ai is cool      1

# %%
df["length"] = df["text"].apply(len)
# Out:
# /tmp/ipykernel_366109/899142544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["length"] = df["text"].apply(len)

# %%
df
# Out:
#          text  label  length
# 0   i love ai      1       9
# 1  this sucks      0      10
# 2  ai is cool      1      10

# %%
df_pos = df[df["label"] == 1]

# %%
df_pos
# Out:
#          text  label  length
# 0   i love ai      1       9
# 2  ai is cool      1      10

# %%
texts = df["text"].tolist()
labels = df["label"].tolist()

# %%
texts, labels
# Out:
# (['i love ai', 'this sucks', 'ai is cool'], [1, 0, 1])

# %%
import pandas as pd
df = pd.read_json("test.jsonl", lines=True)

# %%
df
# Out:
#          text  label
# 0   i love AI      1
# 1  this sucks      0
# 2  AI is cool      1
# 3        None      0

# %%
df = df.dropna()

# %%
df
# Out:
#          text  label
# 0   i love AI      1
# 1  this sucks      0
# 2  AI is cool      1

# %%
df['text'] = df['text'].str.upper()
# Out:
# /tmp/ipykernel_503550/2551732280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.upper()

# %%
df
# Out:
#          text  label
# 0   I LOVE AI      1
# 1  THIS SUCKS      0
# 2  AI IS COOL      1

# %%
df["words"] = df['text'].apply(lambda x: len(x.split()))
# Out:
# /tmp/ipykernel_503550/957883173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["words"] = df['text'].apply(lambda x: len(x.split()))

# %%
df
# Out:
#          text  label  words
# 0   I LOVE AI      1      3
# 1  THIS SUCKS      0      2
# 2  AI IS COOL      1      3

# %%
df_neg = df[df['label'] == 0]

# %%
df_neg
# Out:
#          text  label  words
# 1  THIS SUCKS      0      3

# %%
import pandas as pd
df = pd.read_json("test.jsonl", lines=True)
df = df.dropna()
df['text'] = df['text'].str.upper()
df["words"] = df['text'].apply(lambda x: x.split())
df_neg = df[df['label'] == 0]
