# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()

driver.get("https://quotes.toscrape.com")

driver.find_elements(By.CLASS_NAME, "quote")
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="1291b290c2635c0a006b355d8dc56bc9", element="f.2119B4D823995A63C1C6084961554483.d.4A734E4D2582402FEE971028ACAA53BF.e.11")>]

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 driver.find_elements(" ")
#
# File ~/ml_worl/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:899, in WebDriver.find_elements(self, by, value)
#     895     return self.execute_script(find_element_js, by.to_dict())
#     897 # Return empty list if driver returns null
#     898 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 899 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~/ml_worl/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File ~/ml_worl/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument: invalid locator
#   (Session info: chrome=146.0.7680.177)
# Stacktrace:
# #0 0x557fd7f7436f <unknown>
# #1 0x557fd78f5f38 <unknown>
# #2 0x557fd794a32c <unknown>
# #3 0x557fd794a6e1 <unknown>
# #4 0x557fd79995c2 <unknown>
# #5 0x557fd7996df9 <unknown>
# #6 0x557fd793d8f7 <unknown>
# #7 0x557fd793e662 <unknown>
# #8 0x557fd7f3a3e3 <unknown>
# #9 0x557fd7f3d7e8 <unknown>
# #10 0x557fd7f3d29c <unknown>
# #11 0x557fd7f2994b <unknown>
# #12 0x557fd7f3e094 <unknown>
# #13 0x557fd7f11998 <unknown>
# #14 0x557fd7f5fdf7 <unknown>
# #15 0x557fd7f60064 <unknown>
# #16 0x557fd7f72e08 <unknown>
# #17 0x7f5396cd397a <unknown>
# #18 0x7f5396d572bc <unknown>
